# %% [markdown]
# LIBRARIES PRACTISE

# %%
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install seaborn

# %%
import pandas as pd
from datetime import datetime,timedelta
from matplotlib import dates as mpl_dates
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# from google.colab import files
# upl=files.upload()

# %%
from google.colab import files
upl=files.upload()
# Out:
#      <input type="file" id="files-87ad209f-6765-40ba-806f-fd51e4ab9341" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-87ad209f-6765-40ba-806f-fd51e4ab9341">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
pr=pd.read_csv("products.csv")
pr.head(5)
# Out:
#    Index                                  Name  \
# 0      1  Compact Printer Air Advanced Digital
# 1      2                                Tablet
# 2      3                  Smart Blender Cooker
# 3      4          Advanced Router Rechargeable
# 4      5          Portable Mouse Monitor Phone
#
#                                          Description  \
# 0      Situation organization these memory much off.
# 1        Discussion loss politics free one thousand.
# 2                                  No situation per.
# 3                    For force gas energy six laugh.
# 4  Feeling back religious however author room sci...
#
#                         Brand            Category  Price Currency  Stock  \
# 0     Garner, Boyle and Flynn  Books & Stationery    265      USD    774
# 1                 Mueller Inc    Shoes & Footwear    502      USD     81
# 2  Lawson, Keller and Winters  Kitchen Appliances    227      USD    726
# ...

# %%
plt.figure(figsize=(12,12))
plt.title("STOCK AND THEIR AVAILABILITY")
sns.boxplot(x=pr['Availability'],y=pr['Price'],data=pr,showmeans=True,palette="bright",meanprops={"marker":"o","markersize":"10"})
plt.xlabel("Availability")
plt.ylabel("Price")
plt.legend('mean stock',loc='upper right',ncol=10)
plt.show()
# Out:
# /tmp/ipython-input-3419671529.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=pr['Availability'],y=pr['Price'],data=pr,showmeans=True,palette="bright",meanprops={"marker":"o","markersize":"10"})
